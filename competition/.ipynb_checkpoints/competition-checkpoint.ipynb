# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#import tensorflow as tf
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.svm import SVC,LinearSVC
from sklearn.cluster import KMeans
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.metrics import accuracy_score,confusion_matrix
#from tensorflow.keras.models import Sequential, load_model
#from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
#from tensorflow.keras.wrappers.scikit_learn import KerasRegressor

#from mlxtend.plotting import plot_confusion_matrix

RANDOM_SEED = 2021

# %matplotlib inline

df = pd.read_csv('datasets/training_data.csv',encoding='cp1252')
teste = pd.read_csv('datasets/test_data.csv',encoding='cp1252')

ordem = {'None':0, 'Low':1, 'Medium':2, 'High':3, 'Very_High':4}

#Feriados
feriados = ['2018-01-01', '2018-02-13', '2018-03-30', '2018-04-01', '2018-04-25', '2018-05-01', '2018-05-31', 
            '2018-06-10', '2018-08-15', '2018-10-05', '2018-11-01', '2018-12-01', '2018-12-08', '2018-12-25',
            '2019-01-01', '2019-03-05', '2019-04-19', '2019-04-21', '2019-04-25', '2019-05-01', '2019-06-10', 
            '2019-06-20', '2019-08-15', '2019-10-05', '2019-11-01', '2019-12-01', '2019-12-08', '2019-12-25']

for index,row in df.iterrows():
    data = row[1].split(' ')[0]
    dia = pd.Timestamp(data)
    df.at[index,'Dia'] = dia.day_name()
    if data in feriados:
        df.at[index,'Feriado'] = True
    else:
        df.at[index,'Feriado'] = False
        
for index,row in teste.iterrows():
    data = row[1].split(' ')[0]
    dia = pd.Timestamp(data)
    teste.at[index,'Dia'] = dia.day_name()
    if data in feriados:
        teste.at[index,'Feriado'] = True
    else:
        teste.at[index,'Feriado'] = False

        
del df['AVERAGE_PRECIPITATION']
del teste['AVERAGE_PRECIPITATION']
df['AVERAGE_CLOUDINESS'].fillna(method='bfill',inplace=True)
df['AVERAGE_RAIN'].fillna(method='bfill',inplace=True)
df.dropna(inplace=True)

def round_pred(pred,predictions):
    for n in pred:
        n = int(round(n))
        if n == 0:
            predictions.append('None')
        elif n == 1:
            predictions.append('Low')
        elif n == 2:
            predictions.append('Medium')
        elif n == 3:
            predictions.append('High')
        else:
            predictions.append('Very_High')

            
#teste.loc[teste['Feriado']==True]
df.head()
# Out:
#   city_name          record_date AVERAGE_SPEED_DIFF  AVERAGE_FREE_FLOW_SPEED  \
# 0     Porto  2019-08-29 07:00:00             Medium                     41.5
# 1     Porto  2018-08-10 14:00:00               High                     41.7
# 2     Porto  2019-09-01 16:00:00               High                     38.6
# 3     Porto  2019-02-26 11:00:00               High                     37.4
# 4     Porto  2019-06-06 12:00:00             Medium                     41.6
#
#    AVERAGE_TIME_DIFF  AVERAGE_FREE_FLOW_TIME LUMINOSITY  AVERAGE_TEMPERATURE  \
# 0               11.5                    71.4      LIGHT                 15.0
# 1               48.3                    87.4      LIGHT                 21.0
# 2               38.4                    85.2      LIGHT                 26.0
# 3               61.0                    94.1      LIGHT                 18.0
# 4               50.4                    77.0      LIGHT                 15.0
#
#    AVERAGE_ATMOSP_PRESSURE  AVERAGE_HUMIDITY  AVERAGE_WIND_SPEED  \
# 0                   1019.0             100.0                 3.0
# 1                   1021.0              53.0                 5.0
# 2                   1014.0              61.0                 4.0
# 3                   1025.0              48.0                 4.0
# 4                   1008.0              82.0                10.0
#
#   AVERAGE_CLOUDINESS AVERAGE_RAIN       Dia Feriado
# 0          céu claro  chuva fraca  Thursday   False
# 1          céu claro  chuva fraca    Friday   False
# 2          céu claro  chuva fraca    Sunday   False
# 3          céu claro  chuva fraca   Tuesday   False
# 4   nuvens dispersas  chuva fraca  Thursday   False

# %%
#Remover outliers (correr uma vez)
q = df['AVERAGE_TIME_DIFF'].quantile(0.99)
df = df[df['AVERAGE_TIME_DIFF']<q]

# %%
#Preparação para colocar nos modelos
X = df.drop(['AVERAGE_SPEED_DIFF'],axis=1)
y = df['AVERAGE_SPEED_DIFF'].to_frame()
Y = df['AVERAGE_SPEED_DIFF'].map(ordem)#.to_frame()
#yMLP = df['AVERAGE_SPEED_DIFF'].to_frame()
X_test = teste

city = LabelEncoder()
date = LabelEncoder()
luminosity = LabelEncoder()
cloudiness = LabelEncoder()
rain = LabelEncoder()
feriado = LabelEncoder()
day = LabelEncoder()
city_t = LabelEncoder()
date_t = LabelEncoder()
luminosity_t = LabelEncoder()
cloudiness_t = LabelEncoder()
rain_t = LabelEncoder()
feriado_t = LabelEncoder()
day_t = LabelEncoder()
avg_speed_diff = LabelEncoder()

X['city_name_n'] = city.fit_transform(X['city_name'])
X['record_date_n'] = date.fit_transform(X['record_date'])
X['LUMINOSITY_n'] = luminosity.fit_transform(X['LUMINOSITY'])
X['AVERAGE_CLOUDINESS_n'] = cloudiness.fit_transform(X['AVERAGE_CLOUDINESS'])
X['AVERAGE_RAIN_n'] = rain.fit_transform(X['AVERAGE_RAIN'])
X['Feriado_n'] = feriado.fit_transform(X['Feriado'])
X['Dia_n'] = day.fit_transform(X['Dia'])

X_test['city_name_n'] = city_t.fit_transform(X_test['city_name'])
X_test['record_date_n'] = date_t.fit_transform(X_test['record_date'])
X_test['LUMINOSITY_n'] = luminosity_t.fit_transform(X_test['LUMINOSITY'])
X_test['AVERAGE_CLOUDINESS_n'] = cloudiness_t.fit_transform(X_test['AVERAGE_CLOUDINESS'])
X_test['AVERAGE_RAIN_n'] = rain_t.fit_transform(X_test['AVERAGE_RAIN'])
X_test['Feriado_n'] = feriado_t.fit_transform(X_test['Feriado'])
X_test['Dia_n'] = day_t.fit_transform(X_test['Dia'])

y['AVERAGE_SPEED_DIFF_n'] = avg_speed_diff.fit_transform(y['AVERAGE_SPEED_DIFF'])

y = y.drop(['AVERAGE_SPEED_DIFF'], axis=1)

X_n = X.drop(['city_name', 'record_date', 'LUMINOSITY', 'AVERAGE_CLOUDINESS', 'AVERAGE_RAIN','Dia','Feriado'],axis=1)
X_test_n = X_test.drop(['city_name', 'record_date', 'LUMINOSITY', 'AVERAGE_CLOUDINESS', 'AVERAGE_RAIN','Dia','Feriado'],axis=1)
X_n
# Out:
#       AVERAGE_FREE_FLOW_SPEED  AVERAGE_TIME_DIFF  AVERAGE_FREE_FLOW_TIME  \
# 0                        41.5               11.5                    71.4
# 1                        41.7               48.3                    87.4
# 2                        38.6               38.4                    85.2
# 3                        37.4               61.0                    94.1
# 4                        41.6               50.4                    77.0
# ...                       ...                ...                     ...
# 6797                     40.5               74.2                    78.0
# 6798                     34.2                3.5                    81.6
# 6799                     41.0               51.5                    80.5
# 6800                     42.7              155.9                    86.4
# 6801                     42.2                3.3                    88.0
#
#       AVERAGE_TEMPERATURE  AVERAGE_ATMOSP_PRESSURE  AVERAGE_HUMIDITY  \
# 0                    15.0                   1019.0             100.0
# 1                    21.0                   1021.0              53.0
# 2                    26.0                   1014.0              61.0
# 3                    18.0                   1025.0              48.0
# 4                    15.0                   1008.0              82.0
# ...                   ...                      ...               ...
# 6797                  8.0                   1018.0              93.0
# 6798                 19.0                   1017.0              88.0
# 6799                 10.0                   1008.0              81.0
# 6800                 16.0                   1016.0             100.0
# 6801                 14.0                   1019.0             100.0
#
#       AVERAGE_WIND_SPEED  city_name_n  record_date_n  LUMINOSITY_n  \
# 0                    3.0            0           6170             1
# 1                    5.0            0            326             1
# 2                    4.0            0           6231             1
# 3                    4.0            0           3523             1
# 4                   10.0            0           4785             1
# ...                  ...          ...            ...           ...
# 6797                 3.0            0           2774             0
# 6798                 2.0            0           5340             0
# 6799                 3.0            0           2309             1
# 6800                 1.0            0           6539             1
# 6801                10.0            0           3630             0
#
#       AVERAGE_CLOUDINESS_n  AVERAGE_RAIN_n  Feriado_n  Dia_n
# 0                        1               6          0      4
# 1                        1               6          0      0
# 2                        1               6          0      3
# 3                        1               6          0      5
# 4                        5               6          0      4
# ...                    ...             ...        ...    ...
# 6797                     5               8          0      0
# 6798                     5               8          0      4
# 6799                     5               8          0      6
# 6800                     5               6          0      5
# 6801                     5               6          0      3
#
# [6802 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['city_name', 'record_date', 'AVERAGE_SPEED_DIFF',
#        'AVERAGE_FREE_FLOW_SPEED', 'AVERAGE_TIME_DIFF',
#        'AVERAGE_FREE_FLOW_TIME', 'LUMINOSITY', 'AVERAGE_TEMPERATURE',
#        'AVERAGE_ATMOSP_PRESSURE', 'AVERAGE_HUMIDITY', 'AVERAGE_WIND_SPEED',
#        'AVERAGE_CLOUDINESS', 'AVERAGE_RAIN'],
#       dtype='object')

# %%
df.head()
# Out:
#   city_name          record_date AVERAGE_SPEED_DIFF  AVERAGE_FREE_FLOW_SPEED  \
# 0     Porto  2019-08-29 07:00:00             Medium                     41.5
# 1     Porto  2018-08-10 14:00:00               High                     41.7
# 2     Porto  2019-09-01 16:00:00               High                     38.6
# 3     Porto  2019-02-26 11:00:00               High                     37.4
# 4     Porto  2019-06-06 12:00:00             Medium                     41.6
#
#    AVERAGE_TIME_DIFF  AVERAGE_FREE_FLOW_TIME LUMINOSITY  AVERAGE_TEMPERATURE  \
# 0               11.5                    71.4      LIGHT                 15.0
# 1               48.3                    87.4      LIGHT                 21.0
# 2               38.4                    85.2      LIGHT                 26.0
# 3               61.0                    94.1      LIGHT                 18.0
# 4               50.4                    77.0      LIGHT                 15.0
#
#    AVERAGE_ATMOSP_PRESSURE  AVERAGE_HUMIDITY  AVERAGE_WIND_SPEED  \
# 0                   1019.0             100.0                 3.0
# 1                   1021.0              53.0                 5.0
# 2                   1014.0              61.0                 4.0
# 3                   1025.0              48.0                 4.0
# 4                   1008.0              82.0                10.0
#
#   AVERAGE_CLOUDINESS AVERAGE_RAIN  Feriado
# 0          céu claro  chuva fraca    False
# 1          céu claro  chuva fraca    False
# 2          céu claro  chuva fraca    False
# 3          céu claro  chuva fraca    False
# 4   nuvens dispersas  chuva fraca    False

# %%
df.describe()
# Out:
#        AVERAGE_FREE_FLOW_SPEED  AVERAGE_TIME_DIFF  AVERAGE_FREE_FLOW_TIME  \
# count              6802.000000        6802.000000             6802.000000
# mean                 40.662820          25.644575               81.142782
# std                   4.120387          33.526502                8.293898
# min                  30.500000           0.000000               46.400000
# 25%                  37.600000           2.225000               75.400000
# 50%                  40.700000          12.200000               82.400000
# 75%                  43.500000          36.200000               87.400000
# max                  55.900000         296.500000              112.000000
#
#        AVERAGE_TEMPERATURE  AVERAGE_ATMOSP_PRESSURE  AVERAGE_HUMIDITY  \
# count          6802.000000              6802.000000       6802.000000
# mean             16.195972              1017.382388         80.091517
# std               5.164366                 5.751973         18.233642
# min               0.000000               985.000000         14.000000
# 25%              13.000000              1015.000000         70.000000
# 50%              16.000000              1017.000000         83.000000
# 75%              19.000000              1021.000000         93.000000
# max              35.000000              1033.000000        100.000000
#
#        AVERAGE_WIND_SPEED
# count         6802.000000
# mean             3.058365
# std              2.138831
# min              0.000000
# 25%              1.000000
# 50%              3.000000
# 75%              4.000000
# max             14.000000

# %%
df.isna().any()
# Out:
# city_name                  False
# record_date                False
# AVERAGE_SPEED_DIFF         False
# AVERAGE_FREE_FLOW_SPEED    False
# AVERAGE_TIME_DIFF          False
# AVERAGE_FREE_FLOW_TIME     False
# LUMINOSITY                 False
# AVERAGE_TEMPERATURE        False
# AVERAGE_ATMOSP_PRESSURE    False
# AVERAGE_HUMIDITY           False
# AVERAGE_WIND_SPEED         False
# AVERAGE_CLOUDINESS         False
# AVERAGE_RAIN               False
# Feriado                    False
# dtype: bool

# %%
df[df.duplicated(['record_date'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [city_name, record_date, AVERAGE_SPEED_DIFF, AVERAGE_FREE_FLOW_SPEED, AVERAGE_TIME_DIFF, AVERAGE_FREE_FLOW_TIME, LUMINOSITY, AVERAGE_TEMPERATURE, AVERAGE_ATMOSP_PRESSURE, AVERAGE_HUMIDITY, AVERAGE_WIND_SPEED, AVERAGE_CLOUDINESS, AVERAGE_RAIN]
# Index: []

# %%
df.groupby(by=['LUMINOSITY']).agg(pd.Series.mode)
# Out:
#            city_name                                        record_date  \
# LUMINOSITY
# DARK           Porto  [2018-07-24 21:00:00, 2018-07-25 00:00:00, 201...
# LIGHT          Porto  [2018-07-24 15:00:00, 2018-07-24 16:00:00, 201...
# LOW_LIGHT      Porto  [2018-07-25 06:00:00, 2018-07-25 20:00:00, 201...
#
#            AVERAGE_SPEED_DIFF  AVERAGE_FREE_FLOW_SPEED  AVERAGE_TIME_DIFF  \
# LUMINOSITY
# DARK                     None                     41.9                0.0
# LIGHT                  Medium                     40.0                0.0
# LOW_LIGHT                None                     40.8                0.0
#
#             AVERAGE_FREE_FLOW_TIME  AVERAGE_TEMPERATURE  \
# LUMINOSITY
# DARK                          87.0                 17.0
# LIGHT                         87.4                 20.0
# LOW_LIGHT                     85.7                 18.0
#
#             AVERAGE_ATMOSP_PRESSURE  AVERAGE_HUMIDITY  AVERAGE_WIND_SPEED  \
# LUMINOSITY
# DARK                         1017.0             100.0                 1.0
# LIGHT                        1016.0             100.0                 3.0
# LOW_LIGHT                    1016.0             100.0                 2.0
#
#            AVERAGE_CLOUDINESS AVERAGE_RAIN
# LUMINOSITY
# DARK                céu claro  chuva fraca
# LIGHT               céu claro  chuva fraca
# LOW_LIGHT           céu claro  chuva fraca

# %%
sns.set(rc={'figure.figsize':(10,6)})
sns.boxplot(x=df['AVERAGE_TEMPERATURE'],y=df['AVERAGE_SPEED_DIFF'],order=ordem)
# Out:
# <AxesSubplot:xlabel='AVERAGE_TEMPERATURE', ylabel='AVERAGE_SPEED_DIFF'>

# %%
sns.set(rc={'figure.figsize':(30,15)})
sns.countplot(x=df['AVERAGE_TEMPERATURE'],hue=df['AVERAGE_SPEED_DIFF'])
# Out:
# <AxesSubplot:xlabel='AVERAGE_TEMPERATURE', ylabel='count'>

# %%
sns.histplot(df['AVERAGE_TEMPERATURE'],kde=True)
# Out:
# <AxesSubplot:xlabel='AVERAGE_TEMPERATURE', ylabel='Count'>

# %%
#Decision Tree Classifier

X_train,X_test,y_train,y_test = train_test_split(X_n,y, test_size=0.2, random_state=2)

dtc = DecisionTreeClassifier(random_state= RANDOM_SEED)
dtc.fit(X_n,y)

predictions = dtc.predict(X_test_n)
#predictions

accuracy_score(y_test, predictions)

# cm = confusion_matrix(y_test, predictions)
# plt.figure()
# plot_confusion_matrix(cm, figsize=(12,8), hide_ticks=True, cmap=plt.cm.Blues)
# plt.title("Decision Tree Model - Confusion Matrix")
# plt.xticks(range(2), ["Heart Not Failed","Heart Fail"], fontsize=16)
# plt.yticks(range(2), ["Heart Not Failed","Heart Fail"], fontsize=16)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_38848/1122016900.py in <module>
#       9 #predictions
#      10
# ---> 11 accuracy_score(y_test, predictions)
#      12
#      13 # cm = confusion_matrix(y_test, predictions)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     200
#     201     # Compute accuracy for each possible representation
# --> 202     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     203     check_consistent_length(y_true, y_pred, sample_weight)
#     204     if y_type.startswith('multilabel'):
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      81     y_pred : array or indicator matrix
#      82     """
# ---> 83     check_consistent_length(y_true, y_pred)
#      84     type_true = type_of_target(y_true)
#      85     type_pred = type_of_target(y_pred)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     317     uniques = np.unique(lengths)
#     318     if len(uniques) > 1:
# --> 319         raise ValueError("Found input variables with inconsistent numbers of"
#     320                          " samples: %r" % [int(l) for l in lengths])
#     321
#
# ValueError: Found input variables with inconsistent numbers of samples: [1361, 1500]

# %%
#Linear Regression
lr = LinearRegression()
lr.fit(X_n,Y)

pred = lr.predict(X_test_n)
predictions = []
round_pred(pred,predictions)
        
predictions
# Out:
# ['None',
#  'Low',
#  'None',
#  'Medium',
#  'Low',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'None',
#  'Low',
#  'Medium',
#  'Medium',
#  'Medium',
#  'High',
#  'None',
#  'Medium',
#  'Low',
#  'Low',
#  'None',
#  'None',
#  'Low',
#  'None',
#  'Medium',
#  'Low',
#  'Medium',
#  'Low',
#  'None',
#  'Very_High',
#  'Low',
#  'Low',
#  'Very_High',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Medium',
#  'None',
#  'Low',
#  'None',
#  'Medium',
#  'Very_High',
#  'Medium',
#  'Low',
#  'Low',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'High',
#  'Medium',
#  'None',
#  'Medium',
#  'High',
#  'High',
#  'Very_High',
#  'None',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'Very_High',
#  'None',
#  'Very_High',
#  'Low',
#  'Medium',
#  'Very_High',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'Very_High',
#  'Medium',
#  'Low',
#  'None',
#  'Medium',
#  'Medium',
#  'Low',
#  'Low',
#  'Very_High',
#  'None',
#  'None',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'Medium',
#  'None',
#  'None',
#  'High',
#  'Medium',
#  'None',
#  'High',
#  'None',
#  'None',
#  'High',
#  'Medium',
#  'Low',
#  'None',
#  'None',
#  'Medium',
#  'Low',
#  'Very_High',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'High',
#  'High',
#  'None',
#  'Low',
#  'Medium',
#  'None',
#  'None',
#  'Very_High',
#  'Low',
#  'None',
#  'Low',
#  'Low',
#  'Medium',
#  'High',
#  'Low',
#  'Medium',
#  'Medium',
#  'None',
#  'Medium',
#  'Low',
#  'Medium',
#  'Medium',
#  'Very_High',
#  'Medium',
#  'Medium',
#  'Medium',
#  'High',
#  'Low',
#  'Low',
#  'High',
#  'Very_High',
#  'Medium',
#  'Low',
#  'Medium',
#  'High',
#  'High',
#  'Medium',
#  'None',
#  'Medium',
#  'None',
#  'Low',
#  'Medium',
#  'Very_High',
#  'Low',
#  'Medium',
#  'High',
#  'Medium',
#  'Low',
#  'Medium',
#  'High',
#  'None',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'None',
#  'None',
#  'Medium',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'Medium',
#  'Low',
#  'Very_High',
#  'Low',
#  'Low',
#  'Medium',
#  'Medium',
#  'Medium',
#  'None',
#  'None',
#  'Low',
#  'High',
#  'Medium',
#  'None',
#  'Low',
#  'High',
#  'Medium',
#  'Low',
#  'High',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Low',
#  'None',
#  'High',
#  'Low',
#  'Low',
#  'None',
#  'None',
#  'Low',
#  'High',
#  'Low',
#  'Medium',
#  'None',
#  'Low',
#  'Medium',
#  'High',
#  'None',
#  'Low',
#  'None',
#  'Medium',
#  'Very_High',
#  'High',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Very_High',
#  'Low',
#  'High',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'None',
#  'Medium',
#  'Medium',
#  'None',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Low',
#  'Medium',
#  'None',
#  'Low',
#  'Medium',
#  'Medium',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'High',
#  'Medium',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Very_High',
#  'None',
#  'None',
#  'Medium',
#  'None',
#  'None',
#  'Low',
#  'None',
#  'Medium',
#  'Medium',
#  'None',
#  'Medium',
#  'Very_High',
#  'None',
#  'Low',
#  'Low',
#  'High',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'Low',
#  'None',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'None',
#  'Medium',
#  'None',
#  'Medium',
#  'None',
#  'High',
#  'Low',
#  'Medium',
#  'Medium',
#  'Medium',
#  'Low',
#  'Medium',
#  'None',
#  'Medium',
#  'Low',
#  'Medium',
#  'Low',
#  'High',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Very_High',
#  'Low',
#  'None',
#  'Medium',
#  'Medium',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'High',
#  'Low',
#  'None',
#  'Medium',
#  'Medium',
#  'Low',
#  'High',
#  'None',
#  'Very_High',
#  'Low',
#  'Very_High',
#  'Low',
#  'Low',
#  'High',
#  'High',
#  'None',
#  'Low',
#  'Low',
#  'Medium',
#  'Medium',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'None',
#  'None',
#  'Low',
#  'Low',
#  'None',
#  'None',
#  'High',
#  'Low',
#  'Low',
#  'None',
#  'Low',
#  'Medium',
#  'None',
#  'Low',
#  'None',
#  'Very_High',
#  'Medium',
#  'Medium',
#  'Low',
#  'Medium',
#  'High',
#  'Low',
#  'Medium',
#  'None',
#  'Medium',
#  'None',
#  'Low',
#  'Low',
#  'None',
#  'Very_High',
#  'Low',
#  'High',
#  'None',
#  'Very_High',
#  'Medium',
#  'Low',
#  'Medium',
#  'None',
#  'Low',
#  'Low',
#  'Medium',
#  'None',
#  'Low',
#  'High',
#  'Low',
#  'None',
#  'Medium',
#  'Low',
#  'None',
#  'None',
#  'High',
#  'None',
#  'None',
#  'Low',
#  'Medium',
#  'Low',
#  'Very_High',
#  'Medium',
#  'Low',
#  'Medium',
#  'Low',
#  'High',
#  'Low',
#  'Low',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'High',
#  'High',
#  'Very_High',
#  'Medium',
#  'Low',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'Very_High',
#  'Low',
#  'Low',
#  'None',
#  'None',
#  'Low',
#  'Low',
#  'High',
#  'None',
#  'Low',
#  'Medium',
#  'Low',
#  'Low',
#  'Medium',
#  'None',
#  'None',
#  'Medium',
#  'Low',
#  'Medium',
#  'Medium',
#  'Medium',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'Very_High',
#  'Low',
#  'Low',
#  'Medium',
#  'High',
#  'High',
#  'Low',
#  'Medium',
#  'None',
#  'Very_High',
#  'Medium',
#  'Low',
#  'Low',
#  'Medium',
#  'None',
#  'None',
#  'Very_High',
#  'None',
#  'Medium',
#  'None',
#  'Medium',
#  'Low',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'None',
#  'Low',
#  'Low',
#  'None',
#  'None',
#  'None',
#  'Low',
#  'None',
#  'Low',
#  'Medium',
#  'Low',
#  'Low',
#  'None',
#  'High',
#  'Medium',
#  'Very_High',
#  'None',
#  'Very_High',
#  'None',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'None',
#  'Low',
#  'Medium',
#  'None',
#  'Very_High',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'Medium',
#  'Medium',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'Very_High',
#  'None',
#  'Medium',
#  'High',
#  'None',
#  'Low',
#  'None',
#  'High',
#  'Low',
#  'Very_High',
#  'Medium',
#  'None',
#  'Low',
#  'High',
#  'Low',
#  'High',
#  'None',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Low',
#  'Very_High',
#  'Very_High',
#  'Low',
#  'Low',
#  'Medium',
#  'Medium',
#  'Low',
#  'Low',
#  'None',
#  'Medium',
#  'Low',
#  'Low',
#  'Very_High',
#  'High',
#  'Low',
#  'None',
#  'Medium',
#  'Low',
#  'Medium',
#  'Medium',
#  'None',
#  'Medium',
#  'Low',
#  'Low',
#  'None',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Medium',
#  'Medium',
#  'Medium',
#  'Low',
#  'Medium',
#  'Low',
#  'High',
#  'Medium',
#  'None',
#  'Medium',
#  'Low',
#  'None',
#  'Medium',
#  'None',
#  'Low',
#  'Very_High',
#  'Very_High',
#  'High',
#  'Very_High',
#  'Very_High',
#  'Low',
#  'Medium',
#  'Very_High',
#  'Medium',
#  'Very_High',
#  'Low',
#  'Low',
#  'Medium',
#  'Medium',
#  'Low',
#  'Low',
#  'Medium',
#  'Very_High',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'High',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Medium',
#  'Low',
#  'High',
#  'Low',
#  'Low',
#  'Medium',
#  'Medium',
#  'Medium',
#  'Medium',
#  'Medium',
#  'High',
#  'Low',
#  'Low',
#  'None',
#  'Medium',
#  'Very_High',
#  'Low',
#  'None',
#  'None',
#  'Low',
#  'Medium',
#  'Medium',
#  'Low',
#  'High',
#  'Low',
#  'High',
#  'None',
#  'Low',
#  'None',
#  'Medium',
#  'Medium',
#  'Low',
#  'Low',
#  'Very_High',
#  'Low',
#  'Medium',
#  'Low',
#  'None',
#  'Medium',
#  'High',
#  'Medium',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'None',
#  'Very_High',
#  'Low',
#  'None',
#  'High',
#  'Very_High',
#  'Low',
#  'Very_High',
#  'Low',
#  'None',
#  'Medium',
#  'Low',
#  'None',
#  'Low',
#  'Low',
#  'None',
#  'High',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'High',
#  'Medium',
#  'Medium',
#  'Low',
#  'None',
#  'Low',
#  'Low',
#  'None',
#  'Medium',
#  'Medium',
#  'Medium',
#  'Low',
#  'Medium',
#  'Medium',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Very_High',
#  'Medium',
#  'Medium',
#  'None',
#  'Low',
#  'Medium',
#  'Low',
#  'None',
#  'High',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'Very_High',
#  'Very_High',
#  'Low',
#  'None',
#  'Medium',
#  'Medium',
#  'Low',
#  'Low',
#  'Medium',
#  'None',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'Very_High',
#  'Low',
#  'Low',
#  'Medium',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Medium',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'High',
#  'Medium',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'High',
#  'Low',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Medium',
#  'None',
#  'Low',
#  'Low',
#  'Medium',
#  'High',
#  'None',
#  'High',
#  'Low',
#  'Medium',
#  'Medium',
#  'Low',
#  'Medium',
#  'High',
#  'Low',
#  'Low',
#  'Medium',
#  'Very_High',
#  'Low',
#  'None',
#  'None',
#  'None',
#  'Low',
#  'Low',
#  'High',
#  'Medium',
#  'Medium',
#  'Low',
#  'Low',
#  'Medium',
#  'Very_High',
#  'High',
#  'None',
#  'Medium',
#  'Low',
#  'None',
#  'Low',
#  'Very_High',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'None',
#  'Low',
#  'Low',
#  'Medium',
#  'Medium',
#  'Low',
#  'Low',
#  'Medium',
#  'Medium',
#  'None',
#  'High',
#  'Low',
#  'Medium',
#  'Very_High',
#  'Low',
#  'None',
#  'Medium',
#  'Medium',
#  'Medium',
#  'Low',
#  'Low',
#  'None',
#  'Low',
#  'Very_High',
#  'Low',
#  'None',
#  'None',
#  'Low',
#  'Medium',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'High',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'High',
#  'Low',
#  'None',
#  'Medium',
#  'Low',
#  'Low',
#  'Very_High',
#  'Very_High',
#  'Medium',
#  'Low',
#  'Low',
#  'High',
#  'High',
#  'Medium',
#  'None',
#  'High',
#  'Medium',
#  'High',
#  'Very_High',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'None',
#  'High',
#  'Low',
#  'None',
#  'Medium',
#  'None',
#  'Medium',
#  'None',
#  'Low',
#  'High',
#  'Medium',
#  'None',
#  'Low',
#  'Low',
#  'None',
#  'Very_High',
#  'Low',
#  'Medium',
#  'Medium',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'None',
#  'High',
#  'None',
#  'High',
#  'Medium',
#  'High',
#  'Low',
#  'Low',
#  'High',
#  'Medium',
#  'None',
#  'Medium',
#  'Medium',
#  'Medium',
#  'Low',
#  'None',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'None',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'Low',
#  'High',
#  'None',
#  'High',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'None',
#  'None',
#  'Very_High',
#  'Low',
#  'None',
#  'High',
#  'Low',
#  'None',
#  'None',
#  'Medium',
#  'Very_High',
#  'Low',
#  'Low',
#  'Medium',
#  'Medium',
#  'Low',
#  'None',
#  'Low',
#  ...]

# %%
#Logistic Regression
logr = LogisticRegression(max_iter=10000)
logr.fit(X_n,Y)

pred = logr.predict(X_test_n)
predictions = []
round_pred(pred,predictions)

predictions
# Out:
# C:\Users\tiago\anaconda3\envs\DAA\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ['None',
#  'Low',
#  'None',
#  'Medium',
#  'None',
#  'Medium',
#  'Low',
#  'Medium',
#  'None',
#  'Medium',
#  'None',
#  'None',
#  'Medium',
#  'Medium',
#  'High',
#  'High',
#  'None',
#  'High',
#  'Medium',
#  'None',
#  'None',
#  'None',
#  'Low',
#  'None',
#  'Medium',
#  'Medium',
#  'High',
#  'None',
#  'None',
#  'High',
#  'None',
#  'Low',
#  'Very_High',
#  'Medium',
#  'None',
#  'Low',
#  'Medium',
#  'Medium',
#  'Medium',
#  'None',
#  'None',
#  'None',
#  'High',
#  'Very_High',
#  'High',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Medium',
#  'High',
#  'Medium',
#  'None',
#  'High',
#  'Very_High',
#  'High',
#  'Very_High',
#  'None',
#  'None',
#  'Very_High',
#  'None',
#  'Medium',
#  'High',
#  'None',
#  'High',
#  'Low',
#  'High',
#  'Very_High',
#  'None',
#  'Medium',
#  'Medium',
#  'Medium',
#  'High',
#  'High',
#  'Low',
#  'None',
#  'Medium',
#  'Medium',
#  'Low',
#  'Medium',
#  'Very_High',
#  'None',
#  'None',
#  'Low',
#  'None',
#  'Medium',
#  'None',
#  'High',
#  'Medium',
#  'None',
#  'None',
#  'High',
#  'Medium',
#  'None',
#  'High',
#  'None',
#  'None',
#  'Very_High',
#  'Medium',
#  'Low',
#  'None',
#  'None',
#  'High',
#  'Low',
#  'Very_High',
#  'High',
#  'Low',
#  'None',
#  'Low',
#  'None',
#  'High',
#  'High',
#  'None',
#  'Low',
#  'Medium',
#  'None',
#  'None',
#  'Very_High',
#  'None',
#  'None',
#  'Medium',
#  'Low',
#  'Medium',
#  'High',
#  'Low',
#  'Very_High',
#  'Medium',
#  'None',
#  'Medium',
#  'Low',
#  'Medium',
#  'High',
#  'Very_High',
#  'Medium',
#  'Low',
#  'Medium',
#  'High',
#  'Low',
#  'None',
#  'High',
#  'High',
#  'High',
#  'Low',
#  'Medium',
#  'High',
#  'High',
#  'High',
#  'None',
#  'Medium',
#  'None',
#  'Low',
#  'High',
#  'Very_High',
#  'Low',
#  'Medium',
#  'High',
#  'Medium',
#  'Low',
#  'High',
#  'High',
#  'None',
#  'Low',
#  'Medium',
#  'Low',
#  'High',
#  'Low',
#  'Medium',
#  'None',
#  'None',
#  'Medium',
#  'None',
#  'Low',
#  'Medium',
#  'None',
#  'Low',
#  'Medium',
#  'Medium',
#  'None',
#  'High',
#  'High',
#  'Low',
#  'Very_High',
#  'None',
#  'Low',
#  'Medium',
#  'High',
#  'High',
#  'Low',
#  'None',
#  'Low',
#  'High',
#  'Medium',
#  'None',
#  'Low',
#  'High',
#  'Medium',
#  'Low',
#  'High',
#  'Low',
#  'None',
#  'Medium',
#  'Low',
#  'Low',
#  'None',
#  'High',
#  'Low',
#  'Medium',
#  'None',
#  'None',
#  'None',
#  'High',
#  'Low',
#  'Medium',
#  'None',
#  'Low',
#  'High',
#  'High',
#  'None',
#  'Low',
#  'None',
#  'Medium',
#  'Very_High',
#  'High',
#  'None',
#  'None',
#  'High',
#  'Medium',
#  'Very_High',
#  'None',
#  'High',
#  'None',
#  'Medium',
#  'None',
#  'Low',
#  'None',
#  'Medium',
#  'Medium',
#  'None',
#  'Low',
#  'None',
#  'Medium',
#  'Low',
#  'Low',
#  'High',
#  'None',
#  'None',
#  'Medium',
#  'Medium',
#  'None',
#  'Medium',
#  'Medium',
#  'Medium',
#  'High',
#  'High',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'None',
#  'None',
#  'Medium',
#  'Low',
#  'Medium',
#  'Medium',
#  'Medium',
#  'Low',
#  'Low',
#  'Medium',
#  'None',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Very_High',
#  'None',
#  'None',
#  'High',
#  'None',
#  'None',
#  'Low',
#  'None',
#  'Medium',
#  'Medium',
#  'None',
#  'Medium',
#  'Very_High',
#  'None',
#  'Low',
#  'Low',
#  'High',
#  'None',
#  'Medium',
#  'Low',
#  'Medium',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'Low',
#  'None',
#  'Medium',
#  'Medium',
#  'None',
#  'None',
#  'Low',
#  'None',
#  'Low',
#  'None',
#  'Medium',
#  'None',
#  'Very_High',
#  'None',
#  'Medium',
#  'Very_High',
#  'Medium',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'None',
#  'Medium',
#  'None',
#  'High',
#  'High',
#  'Low',
#  'Medium',
#  'Low',
#  'None',
#  'Low',
#  'None',
#  'Very_High',
#  'None',
#  'None',
#  'High',
#  'Medium',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'None',
#  'High',
#  'None',
#  'None',
#  'Medium',
#  'Medium',
#  'Low',
#  'High',
#  'None',
#  'Very_High',
#  'Medium',
#  'Very_High',
#  'Low',
#  'None',
#  'High',
#  'High',
#  'None',
#  'None',
#  'Medium',
#  'Very_High',
#  'Medium',
#  'Medium',
#  'Low',
#  'Medium',
#  'None',
#  'Low',
#  'Low',
#  'Medium',
#  'None',
#  'None',
#  'Low',
#  'Low',
#  'None',
#  'None',
#  'Very_High',
#  'None',
#  'None',
#  'None',
#  'Low',
#  'Medium',
#  'None',
#  'Low',
#  'None',
#  'High',
#  'Medium',
#  'Medium',
#  'None',
#  'Medium',
#  'High',
#  'None',
#  'Medium',
#  'None',
#  'Medium',
#  'None',
#  'Low',
#  'None',
#  'None',
#  'High',
#  'Low',
#  'Very_High',
#  'None',
#  'High',
#  'Medium',
#  'Low',
#  'Medium',
#  'None',
#  'None',
#  'Low',
#  'Medium',
#  'None',
#  'Low',
#  'High',
#  'Low',
#  'None',
#  'Medium',
#  'Medium',
#  'None',
#  'None',
#  'High',
#  'Low',
#  'Low',
#  'None',
#  'Low',
#  'Low',
#  'High',
#  'Medium',
#  'Medium',
#  'Medium',
#  'Low',
#  'High',
#  'Medium',
#  'Low',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'High',
#  'High',
#  'Very_High',
#  'High',
#  'Low',
#  'High',
#  'Low',
#  'Medium',
#  'Low',
#  'High',
#  'Medium',
#  'Low',
#  'None',
#  'None',
#  'None',
#  'Medium',
#  'High',
#  'None',
#  'Low',
#  'Medium',
#  'None',
#  'None',
#  'Medium',
#  'None',
#  'None',
#  'Medium',
#  'Medium',
#  'Low',
#  'Medium',
#  'Medium',
#  'Medium',
#  'None',
#  'None',
#  'Low',
#  'Very_High',
#  'Low',
#  'Low',
#  'Medium',
#  'High',
#  'High',
#  'Low',
#  'Medium',
#  'None',
#  'Very_High',
#  'Medium',
#  'Low',
#  'Medium',
#  'Medium',
#  'None',
#  'None',
#  'High',
#  'None',
#  'High',
#  'None',
#  'High',
#  'Low',
#  'None',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'High',
#  'None',
#  'None',
#  'Medium',
#  'Medium',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'High',
#  'Low',
#  'Low',
#  'None',
#  'Very_High',
#  'Medium',
#  'Very_High',
#  'None',
#  'Very_High',
#  'None',
#  'None',
#  'Medium',
#  'Medium',
#  'Low',
#  'None',
#  'None',
#  'High',
#  'None',
#  'Very_High',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'Low',
#  'High',
#  'Low',
#  'Medium',
#  'None',
#  'High',
#  'High',
#  'None',
#  'Medium',
#  'High',
#  'None',
#  'None',
#  'None',
#  'High',
#  'None',
#  'Very_High',
#  'Medium',
#  'None',
#  'None',
#  'High',
#  'Low',
#  'High',
#  'None',
#  'Medium',
#  'Low',
#  'Low',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Low',
#  'Very_High',
#  'Very_High',
#  'None',
#  'Low',
#  'High',
#  'High',
#  'Low',
#  'Low',
#  'None',
#  'High',
#  'Low',
#  'None',
#  'Very_High',
#  'Very_High',
#  'None',
#  'None',
#  'Medium',
#  'None',
#  'Very_High',
#  'Medium',
#  'None',
#  'High',
#  'None',
#  'None',
#  'None',
#  'None',
#  'Medium',
#  'None',
#  'Low',
#  'Medium',
#  'Medium',
#  'Medium',
#  'High',
#  'Low',
#  'Low',
#  'None',
#  'High',
#  'High',
#  'None',
#  'Medium',
#  'None',
#  'None',
#  'Medium',
#  'None',
#  'None',
#  'Very_High',
#  'Very_High',
#  'High',
#  'Very_High',
#  'Very_High',
#  'Low',
#  'High',
#  'Very_High',
#  'Medium',
#  'High',
#  'Low',
#  'None',
#  'Medium',
#  'Medium',
#  'Low',
#  'Low',
#  'High',
#  'Very_High',
#  'Low',
#  'Low',
#  'None',
#  'None',
#  'Very_High',
#  'None',
#  'None',
#  'None',
#  'Medium',
#  'Medium',
#  'Medium',
#  'High',
#  'None',
#  'None',
#  'Medium',
#  'Medium',
#  'Medium',
#  'High',
#  'Low',
#  'High',
#  'None',
#  'None',
#  'None',
#  'Medium',
#  'High',
#  'None',
#  'None',
#  'None',
#  'Low',
#  'High',
#  'High',
#  'Low',
#  'High',
#  'Low',
#  'High',
#  'None',
#  'None',
#  'None',
#  'Medium',
#  'High',
#  'Low',
#  'Low',
#  'Very_High',
#  'Low',
#  'High',
#  'None',
#  'None',
#  'Medium',
#  'Very_High',
#  'High',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Medium',
#  'Low',
#  'None',
#  'Very_High',
#  'Medium',
#  'None',
#  'High',
#  'Very_High',
#  'Medium',
#  'Very_High',
#  'Medium',
#  'None',
#  'Medium',
#  'Medium',
#  'None',
#  'None',
#  'Low',
#  'None',
#  'High',
#  'None',
#  'Low',
#  'Low',
#  'None',
#  'Low',
#  'None',
#  'High',
#  'Medium',
#  'High',
#  'High',
#  'High',
#  'Medium',
#  'Low',
#  'None',
#  'Medium',
#  'None',
#  'None',
#  'High',
#  'Medium',
#  'High',
#  'Low',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'High',
#  'Low',
#  'Very_High',
#  'Medium',
#  'High',
#  'Low',
#  'Medium',
#  'Medium',
#  'Low',
#  'None',
#  'High',
#  'None',
#  'Low',
#  'Low',
#  'Low',
#  'Very_High',
#  'Very_High',
#  'Low',
#  'None',
#  'Medium',
#  'Very_High',
#  'Low',
#  'Low',
#  'Low',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'High',
#  'Low',
#  'None',
#  'High',
#  'None',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'High',
#  'None',
#  'Medium',
#  'Low',
#  'None',
#  'Medium',
#  'High',
#  'Medium',
#  'None',
#  'Low',
#  'High',
#  'Medium',
#  'Medium',
#  'High',
#  'Low',
#  'High',
#  'Low',
#  'Medium',
#  'Medium',
#  'Medium',
#  'Medium',
#  'None',
#  'Low',
#  'Medium',
#  'Low',
#  'High',
#  'None',
#  'High',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'High',
#  'Low',
#  'Medium',
#  'High',
#  'Very_High',
#  'None',
#  'None',
#  'None',
#  'None',
#  'Low',
#  'Low',
#  'Very_High',
#  'Medium',
#  'Medium',
#  'Low',
#  'None',
#  'High',
#  'Very_High',
#  'High',
#  'None',
#  'High',
#  'None',
#  'Low',
#  'Low',
#  'Very_High',
#  'None',
#  'None',
#  'Low',
#  'None',
#  'Low',
#  'None',
#  'Medium',
#  'None',
#  'None',
#  'Medium',
#  'None',
#  'High',
#  'High',
#  'None',
#  'Low',
#  'Medium',
#  'High',
#  'None',
#  'Very_High',
#  'Low',
#  'Medium',
#  'High',
#  'Low',
#  'None',
#  'High',
#  'High',
#  'Medium',
#  'Low',
#  'Medium',
#  'None',
#  'Low',
#  'Very_High',
#  'Medium',
#  'None',
#  'None',
#  'None',
#  'High',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'Medium',
#  'Medium',
#  'Medium',
#  'Low',
#  'Medium',
#  'None',
#  'Medium',
#  'Low',
#  'Medium',
#  'High',
#  'Low',
#  'None',
#  'Medium',
#  'Medium',
#  'High',
#  'Low',
#  'None',
#  'Medium',
#  'Medium',
#  'None',
#  'High',
#  'High',
#  'Medium',
#  'Low',
#  'Low',
#  'High',
#  'High',
#  'Medium',
#  'None',
#  'Medium',
#  'Medium',
#  'High',
#  'Very_High',
#  'Medium',
#  'Medium',
#  'Low',
#  'Medium',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Medium',
#  'None',
#  'High',
#  'Low',
#  'None',
#  'Medium',
#  'None',
#  'High',
#  'None',
#  'Low',
#  'High',
#  'Medium',
#  'None',
#  'Low',
#  'Low',
#  'None',
#  'Very_High',
#  'Very_High',
#  'Medium',
#  'Medium',
#  'None',
#  'Medium',
#  'Low',
#  'None',
#  'Low',
#  'Low',
#  'Medium',
#  'Medium',
#  'None',
#  'Low',
#  'None',
#  'Very_High',
#  'None',
#  'High',
#  'Medium',
#  'High',
#  'Low',
#  'None',
#  'High',
#  'High',
#  'None',
#  'Medium',
#  'High',
#  'Medium',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'Low',
#  'Low',
#  'High',
#  'None',
#  'Medium',
#  'None',
#  'None',
#  'Low',
#  'High',
#  'Low',
#  'Medium',
#  'Low',
#  'Very_High',
#  'None',
#  'High',
#  'Medium',
#  'None',
#  'Low',
#  'Low',
#  'None',
#  'None',
#  'Very_High',
#  'None',
#  'None',
#  'High',
#  'None',
#  'None',
#  'None',
#  'Medium',
#  'High',
#  'Low',
#  'Low',
#  'High',
#  'Very_High',
#  'None',
#  'None',
#  'None',
#  ...]

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
#scaler_X = MinMaxScaler(feature_range=(0,1)).fit(X_n)
#scaler_yMLP = MinMaxScaler(feature_range=(0,1)).fit(yMLP_n)
#X_scaled = pd.DataFrame(scaler_X.transform(X_n[X_n.columns]), columns = X_n.columns)
#yMLP_scaled = pd.DataFrame(scaler_yMLP.transform(yMLP_n[yMLP_n.columns]), columns = yMLP_n.columns)

#def build_model(activation='relu', learning_rate=0.01):
#    model = Sequential()
#    model.add(Dense(16, input_dim=5, activation = activation))
#    model.add(Dense(8, activation=activation))
#    model.add(Dense(1, activation='relu'))
    
#    model.compile(
#        loss = 'mae',
#        optimizer = tf.optimizers.Adam(learning_rate),
#        metrics = ['mae', 'mse'])
#    return model

#X_train, X_test, y_train, y_test = train_test_split(X_scaled, yMLP_scaled, test_size=0.2, random_state=RANDOM_SEED)

#TUNING_DICT = {
#    'activation' : ['relu', 'sigmoid'],
#    'learning_rate' : [0.01, 0.001]
#}

#kf = KFold(n_splits=5, shuffle=True, random_state = RANDOM_SEED)

#model = KerasRegressor(build_fn=build_model, epochs=20, batch_size=32)
#grid_search = GridSearchCV(estimator = model,
                          param_grid = TUNING_DICT,
                          cv = kf,
                          scoring = 'neg_mean_absolute_error',
                          refit = 'True',
                          verbose = 1)
#grid_search.fit(X_train, y_train, validation_split=0.2, verbose=1)

# %%
#TensorFlow
#X__ = np.asarray(X_n).astype('float32')
print(y.dtypes)
model = Sequential()
model.add(Dense(units=32, activation='relu', input_dim=len(X_n.columns)))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics='accuracy')
model.fit(X_n,y,epochs=100,batch_size=32)
predictions = model.predict(X_test_n)
predictions
# Out:
# AVERAGE_SPEED_DIFF_n    int32
# dtype: object
# Epoch 1/100
# 107/107 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.1577
# Epoch 2/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 3/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 4/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 5/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 6/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 7/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 8/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 9/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 10/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 11/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 12/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 13/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 14/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 15/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 16/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 17/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 18/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 19/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 20/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 21/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 22/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 23/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 24/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 25/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 26/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 27/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 28/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 29/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 30/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 31/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 32/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 33/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 34/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 35/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 36/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 37/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 38/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 39/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 40/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 41/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 42/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 43/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 44/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 45/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 46/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 47/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 48/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 49/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 50/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 51/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 52/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 53/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 54/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 55/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 56/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 57/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 58/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 59/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 60/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 61/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.1560
# Epoch 62/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.1560
# Epoch 63/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.1560
# Epoch 64/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.1560
# Epoch 65/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 66/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.1560
# Epoch 67/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 68/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 69/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 70/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 71/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 72/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 73/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 74/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 75/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 76/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 77/100
# 107/107 [==============================] - ETA: 0s - loss: nan - accuracy: 0.150 - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 78/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 79/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 80/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 81/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 82/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 83/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 84/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 85/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 86/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 87/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 88/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 89/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 90/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 91/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 92/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 93/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 94/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 95/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 96/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 97/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 98/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 99/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# Epoch 100/100
# 107/107 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1560
# array([[nan],
#        [nan],
#        [nan],
#        ...,
#        [nan],
#        [nan],
#        [nan]], dtype=float32)

# %%
submission = open("submissions/submission12.csv", "w", newline='')
writer = csv.writer(submission)
writer.writerow(['RowId', 'Speed_Diff'])
rowId = list(range(0, 1500))
for i in range(1500):
    writer.writerow([rowId[i]+1, predictions[i]])

submission.close()
